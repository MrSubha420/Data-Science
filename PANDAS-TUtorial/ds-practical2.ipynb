# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/studentdata/data.csv
# /kaggle/input/weather-dataset/weather_monitoring_data.csv

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Name': ['A', 'B', 'C'],
    'Age': [23, 25, 21]
})

print(df)
# Out:
#   Name  Age
# 0    A   23
# 1    B   25
# 2    C   21

# %%
df2 = pd.read_csv("/kaggle/input/studentdata/data.csv")
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df2.head()
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Age         5 non-null      int64
#  3   Gender      5 non-null      object
#  4   Department  5 non-null      object
#  5   Semester    5 non-null      int64
#  6   CGPA        5 non-null      float64
#  7   Contact_No  5 non-null      int64
#  8   Email       5 non-null      object
#  9   Address     5 non-null      object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 532.0+ bytes

# %%
df2.describe()
# Out:
#        Student_ID       Age  Semester     CGPA    Contact_No
# count    5.000000   5.00000   5.00000  5.00000  5.000000e+00
# mean   103.000000  19.20000   2.40000  8.30000  9.352692e+09
# std      1.581139   1.30384   1.67332  0.65192  8.857629e+08
# min    101.000000  18.00000   1.00000  7.50000  7.894561e+09
# 25%    102.000000  18.00000   1.00000  7.90000  9.123457e+09
# 50%    103.000000  19.00000   2.00000  8.20000  9.870012e+09
# 75%    104.000000  20.00000   3.00000  8.80000  9.876543e+09
# max    105.000000  21.00000   5.00000  9.10000  9.998888e+09

# %%
df2.shape
# Out:
# (5, 10)

# %%
df2.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'Semester', 'CGPA',
#        'Contact_No', 'Email', 'Address'],
#       dtype='object')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df3=df2['Name']
print(df3)
# Out:
# 0     Amit
# 1     Riya
# 2    Sohan
# 3    Priya
# 4    Rahul
# Name: Name, dtype: object

# %%
#df2.loc[2]          # By label
#df2.iloc[2]         # By index
df2.loc[2:5]        # Slice rows
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df5=df2[(df2['Age'] > 20) & (df2['Age']<25)]
print(df5)
# Out:
#    Student_ID   Name  Age Gender Department  Semester  CGPA  Contact_No  \
# 4         105  Rahul   21   Male         IT         2   7.9  9870012345
#
#                Email Address
# 4  rahul@example.com    Pune

# %%
df2['new_col'] = df2['Age'] + 5


print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   30    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address  new_col
# 0   amit@example.com  Kolkata       35
# 1   riya@example.com    Delhi       24
# 2  sohan@example.com   Mumbai       25
# 3  priya@example.com  Chennai       23
# 4  rahul@example.com     Pune       26

# %%
df2["new_col"] = df2["Age"] + 5
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   30    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address  new_col
# 0   amit@example.com  Kolkata       35
# 1   riya@example.com    Delhi       24
# 2  sohan@example.com   Mumbai       25
# 3  priya@example.com  Chennai       23
# 4  rahul@example.com     Pune       26

# %%
df2.loc[0, "Age"] = 30     # Update Amit’s age to 30
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   30    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address  new_col
# 0   amit@example.com  Kolkata       35
# 1   riya@example.com    Delhi       24
# 2  sohan@example.com   Mumbai       25
# 3  priya@example.com  Chennai       23
# 4  rahul@example.com     Pune       26

# %%
df2.drop("new_col", axis=1, inplace=True)
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   30    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df2.drop([0, 3], axis=0)
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   30    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df6=df2

# %%
print(df6)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   30    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df2.head()
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         102   Riya   19  Female        ECE         3   8.8  9123456780
# 1         103  Sohan   20    Male         ME         5   7.5  9998887776
# 2         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email Address
# 0   riya@example.com   Delhi
# 1  sohan@example.com  Mumbai
# 2  rahul@example.com    Pune

# %%
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         102   Riya   19  Female        ECE         3   8.8  9123456780
# 1         103  Sohan   20    Male         ME         5   7.5  9998887776
# 2         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email Address
# 0   riya@example.com   Delhi
# 1  sohan@example.com  Mumbai
# 2  rahul@example.com    Pune

# %%
df2=pd.read_csv('/kaggle/input/studentdata/data.csv')

# %%
df2.head()
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  Priya   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df6=df2

# %%
df6.drop([0, 3], axis=0, inplace=True)

# %%
df6.head()
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email Address
# 1   riya@example.com   Delhi
# 2  sohan@example.com  Mumbai
# 4  rahul@example.com    Pune

# %%
df2.isnull()
# Out:
#    Student_ID   Name    Age  Gender  Department  Semester   CGPA  Contact_No  \
# 0       False  False  False   False       False     False  False       False
# 1       False  False  False   False       False     False  False       False
# 2       False  False  False   False       False     False  False       False
# 3       False  False  False   False       False     False  False       False
# 4       False  False  False   False       False     False  False       False
#
#    Email  Address
# 0  False    False
# 1  False    False
# 2  False    False
# 3  False    False
# 4  False    False

# %%
import numpy as np
df2.loc[3, "Name"] = np.nan

# %%
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104    NaN   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df2.isnull()
# Out:
#    Student_ID   Name    Age  Gender  Department  Semester   CGPA  Contact_No  \
# 0       False  False  False   False       False     False  False       False
# 1       False  False  False   False       False     False  False       False
# 2       False  False  False   False       False     False  False       False
# 3       False   True  False   False       False     False  False       False
# 4       False  False  False   False       False     False  False       False
#
#    Email  Address
# 0  False    False
# 1  False    False
# 2  False    False
# 3  False    False
# 4  False    False

# %%
df7=df2

# %%
print(df7)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104    NaN   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df7.dropna()#drop row
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 4  rahul@example.com     Pune

# %%
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104    NaN   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df2.fillna(0)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104      0   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df2.fillna("subha")
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104  subha   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
import numpy as np
df2.loc[3, "Name"] = np.nan

# %%
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male         ME         5   7.5  9998887776
# 3         104    NaN   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
df2["Department"].fillna("CSE")
# Out:
# 0    CSE
# 1    ECE
# 2    ECE
# 3    CSE
# 4     IT
# Name: Department, dtype: object

# %%
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male        NaN         5   7.5  9998887776
# 3         104    NaN   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune

# %%
print(df2)
# Out:
#    Student_ID   Name  Age  Gender Department  Semester  CGPA  Contact_No  \
# 0         101   Amit   18    Male        CSE         1   8.2  9876543210
# 1         102   Riya   19  Female        ECE         3   8.8  9123456780
# 2         103  Sohan   20    Male        ECE         5   7.5  9998887776
# 3         104    NaN   18  Female        CSE         1   9.1  7894561230
# 4         105  Rahul   21    Male         IT         2   7.9  9870012345
#
#                Email  Address
# 0   amit@example.com  Kolkata
# 1   riya@example.com    Delhi
# 2  sohan@example.com   Mumbai
# 3  priya@example.com  Chennai
# 4  rahul@example.com     Pune
